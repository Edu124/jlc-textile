# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import torch

# Path to your base model and adapter
# Update these paths to match where your files are
BASE_MODEL = "Qwen/Qwen2.5-1.5B-Instruct"
ADAPTER_PATH = r"D:\offlineai\models"

print("Loading base model...")
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    torch_dtype = torch.float32,
    device_map = "cpu"
)

print("Loading your fine-tuned adapter...")
model = PeftModel.from_pretrained(model, ADAPTER_PATH)
model.eval()

print("✅ Your fine-tuned Qwen loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2249, in _LazyModule.__getattr__(self, name)
#    2248 try:
# -> 2249     module = self._get_module(self._class_to_module[name])
#    2250     value = getattr(module, name)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2483, in _LazyModule._get_module(self, module_name)
#    2482 except Exception as e:
# -> 2483     raise e
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2481, in _LazyModule._get_module(self, module_name)
#    2480 try:
# -> 2481     return importlib.import_module("." + module_name, self.__name__)
#    2482 except Exception as e:
#
# ...

# %%
# !pip install transformers peft accelerate
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import torch

# Update ADAPTER_PATH to where you extracted the files
BASE_MODEL = "Qwen/Qwen2.5-1.5B-Instruct"
ADAPTER_PATH = r"C:\Users\ASUS\Desktop\JLC\codeforge-training\porters_qwen_adapter"

print("Loading base model...")
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    torch_dtype = torch.float32,
    device_map = "cpu"
)

print("Loading your fine-tuned adapter...")
model = PeftModel.from_pretrained(model, ADAPTER_PATH)
model.eval()

print("✅ Your fine-tuned Qwen loaded successfully!")
